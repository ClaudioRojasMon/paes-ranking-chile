# %%
import pandas as pd

# %%
PAES2024 = 'ArchivoC_Adm2024.csv'
df = pd.read_csv(PAES2024,sep=';')  # También puedes usar sep=';'

# Mostrar las primeras filas
print(df.head())
# Out:
#              ID_aux      RBD  COD_ENS  GRUPO_DEPENDENCIA RAMA_EDUCACIONAL  \
# 0  id_0000900470001  10399.0    410.0                3.0               T1
# 1  id_0000900470008   8553.0    363.0                3.0               H2
# 2  id_0001900470101  25502.0    363.0                2.0               H2
# 3  id_0001900470177      NaN      NaN                NaN              NaN
# 4  id_0001900670170  40320.0    310.0                2.0               H1
#
#    SITUACION_EGRESO  CODIGO_REGION  CODIGO_COMUNA PROMEDIO_NOTAS  \
# 0                 5           13.0        13301.0           5,38
# 1                 5           13.0        13127.0           5,85
# 2                 5           13.0        13107.0            5,2
# 3                 1            NaN            NaN              0
# 4                 5            1.0         1101.0           6,33
#
#    PORC_SUP_NOTAS  ...  MATE1_REG_ANTERIOR  MATE2_REG_ANTERIOR  \
# 0              40  ...                 NaN                 NaN
# 1              30  ...                 NaN                 NaN
# 2              30  ...                 NaN                 NaN
# 3               0  ...                 NaN                 NaN
# 4              10  ...                 NaN                 NaN
#
#    HCSOC_REG_ANTERIOR  CIEN_REG_ANTERIOR  MODULO_REG_ANTERIOR  \
# 0                 NaN                NaN                  NaN
# 1                 NaN                NaN                  NaN
# 2                 NaN                NaN                  NaN
# 3                 NaN                NaN                  NaN
# 4                 NaN                NaN                  NaN
#
#    CLEC_INV_ANTERIOR  MATE_INV_ANTERIOR HCSOC_INV_ANTERIOR  CIEN_INV_ANTERIOR  \
# 0                NaN                NaN                NaN                NaN
# 1                NaN                NaN                NaN                NaN
# 2                NaN                NaN                NaN                NaN
# 3                NaN                NaN                NaN                NaN
# 4                NaN                NaN                NaN                NaN
#
#    MODULO_INV_ANTERIOR
# 0                  NaN
# 1                  NaN
# 2                  NaN
# 3                  NaN
# 4                  NaN
#
# [5 rows x 35 columns]
# <ipython-input-2-153b97bbab19>:2: DtypeWarning: Columns (34) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(PAES2024,sep=';')  # También puedes usar sep=';'

# %%
# b) Calcular promedios por RBD para estudiantes con SITUACION_EGRESO = 1
filtered_data = df[df['SITUACION_EGRESO'] == 1]
columns_to_average = ['CLEC_REG_ACTUAL', 'MATE1_REG_ACTUAL', 'MATE2_REG_ACTUAL', 'HCSOC_REG_ACTUAL', 'CIEN_REG_ACTUAL']
rbd_averages = filtered_data.groupby('RBD')[columns_to_average].mean().reset_index()

# %%
# c) Calcular el promedio de CLEC_REG_ACTUAL y MATE1_REG_ACTUAL por RBD
columns_paes = ['CLEC_REG_ACTUAL', 'MATE1_REG_ACTUAL']
rbd_paes_average = filtered_data.groupby('RBD')[columns_paes].mean()
rbd_paes_average['PAES_PROMEDIO'] = rbd_paes_average.mean(axis=1)
rbd_paes_average = rbd_paes_average.reset_index()

# %%
# d) Crear un ranking de colegios basado en PAES_PROMEDIO
rbd_paes_average['RANK'] = rbd_paes_average['PAES_PROMEDIO'].rank(ascending=False, method='min')
rbd_paes_average = rbd_paes_average.sort_values('PAES_PROMEDIO', ascending=False).reset_index(drop=True)

# %%
# Función para consultar el lugar de un colegio dado su RBD
def obtener_posicion(rbd):
    resultado = rbd_paes_average[rbd_paes_average['RBD'] == rbd]
    if resultado.empty:
        return f"El RBD {rbd} no se encuentra en el ranking."
    else:
        return resultado[['RBD', 'PAES_PROMEDIO', 'RANK']]

# %%
# Mostrar resultados
print("Promedios obtenidos por estudiantes para cada RBD:\n", rbd_averages)
print("\nPromedio PAES por RBD:\n", rbd_paes_average)
# Out:
# Promedios obtenidos por estudiantes para cada RBD:
#            RBD  CLEC_REG_ACTUAL  MATE1_REG_ACTUAL  MATE2_REG_ACTUAL  \
# 0         1.0       319.966292        342.988764        148.471910
# 1         4.0       600.179856        607.205036        173.866906
# 2         5.0       474.396825        486.873016        141.380952
# 3         7.0       390.613043        391.978261        168.213043
# 4         8.0       482.263158        462.078947         97.763158
# ...       ...              ...               ...               ...
# 3279  41846.0       294.769231        331.923077        271.923077
# 3280  41872.0        56.700000          0.000000          0.000000
# 3281  41899.0       677.500000        682.694444        168.388889
# 3282  42158.0       186.500000        147.166667          0.000000
# 3283  42168.0       301.333333        323.916667        157.083333
#
#       HCSOC_REG_ACTUAL  CIEN_REG_ACTUAL
# 0           214.786517       169.033708
# 1           277.309353       331.053957
# 2           269.761905       256.555556
# 3           222.952174       219.656522
# 4           311.526316       203.868421
# ...                ...              ...
# 3279        269.076923       237.615385
# 3280          0.000000        40.700000
# 3281        247.472222       422.222222
# 3282         46.277778       143.833333
# 3283         75.166667       248.500000
#
# [3284 rows x 6 columns]
#
# Promedio PAES por RBD:
#            RBD  CLEC_REG_ACTUAL  MATE1_REG_ACTUAL  PAES_PROMEDIO    RANK
# 0      8862.0       795.205607        934.224299     864.714953     1.0
# 1     24979.0       801.846154        919.015385     860.430769     2.0
# 2      8903.0       808.038462        897.730769     852.884615     3.0
# 3      8998.0       788.275862        909.620690     848.948276     4.0
# 4      9046.0       784.119048        911.960317     848.039683     5.0
# ...       ...              ...               ...            ...     ...
# 3279  17698.0        37.833333         36.333333      37.083333  3280.0
# 3280  41872.0        56.700000          0.000000      28.350000  3281.0
# 3281   3291.0        29.176471          0.000000      14.588235  3282.0
# 3282  22446.0         0.000000          0.000000       0.000000  3283.0
# 3283  16847.0         0.000000          0.000000       0.000000  3283.0
#
# [3284 rows x 5 columns]

# %%
# Ejemplo de consulta de ranking
rbd = int(input("\nIngrese el RBD para consultar el ranking: "))
print(obtener_posicion(rbd))
# Out:
# Ingrese el RBD para consultar el ranking:  7406
#         RBD  PAES_PROMEDIO   RANK
# 192  7406.0     729.568182  193.0
