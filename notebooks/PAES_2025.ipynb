# %%
import pandas as pd

# %%
PAES2025 = 'ArchivoC_Adm2025REG.csv'
df = pd.read_csv(PAES2025,sep=';')  # También puedes usar sep=';'

# Mostrar las primeras filas
print(df.head())
# Out:
#             ID_aux      RBD  COD_ENS  GRUPO_DEPENDENCIA RAMA_EDUCACIONAL  \
# 0  id_815728178577  11284.0    363.0                3.0               H2
# 1  id_985329876535  20356.0    363.0                2.0               H2
# 2  id_767127676717  14846.0    363.0                2.0               H2
# 3  id_112621173264      NaN      NaN                NaN              NaN
# 4  id_497424971745  22633.0    363.0                2.0               H2
#
#    SITUACION_EGRESO  CODIGO_REGION  CODIGO_COMUNA PROMEDIO_NOTAS  \
# 0                 1            6.0         6101.0              0
# 1                 1            4.0         4101.0           6,55
# 2                 1            5.0         5101.0            6,6
# 3                 5            NaN            NaN           6,15
# 4                 1           14.0        14101.0            6,4
#
#    PORC_SUP_NOTAS  ...  MATE2_REG_ANTERIOR  HCSOC_REG_ANTERIOR  \
# 0               0  ...                 NaN                 NaN
# 1              10  ...                 NaN                 NaN
# 2              10  ...                 NaN                 NaN
# 3              10  ...               616.0                 0.0
# 4              10  ...                 NaN                 NaN
#
#    CIEN_REG_ANTERIOR  MODULO_REG_ANTERIOR  CLEC_INV_ANTERIOR  \
# 0                NaN                  NaN                NaN
# 1                NaN                  NaN                NaN
# 2                NaN                  NaN                NaN
# 3                0.0                  NaN                NaN
# 4                NaN                  NaN                NaN
#
#    MATE1_INV_ANTERIOR  MATE2_INV_ANTERIOR HCSOC_INV_ANTERIOR  \
# 0                 NaN                 NaN                NaN
# 1                 NaN                 NaN                NaN
# 2                 NaN                 NaN                NaN
# 3                 NaN                 NaN                NaN
# 4                 NaN                 NaN                NaN
#
#    CIEN_INV_ANTERIOR  MODULO_INV_ANTERIOR
# 0                NaN                  NaN
# 1                NaN                  NaN
# 2                NaN                  NaN
# 3                NaN                  NaN
# 4                NaN                  NaN
#
# [5 rows x 36 columns]
# <ipython-input-2-8e8bcfa139b2>:2: DtypeWarning: Columns (35) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(PAES2025,sep=';')  # También puedes usar sep=';'

# %%
import os
print(os.path.isfile(PAES2025))  # Devuelve True si el archivo existe
# Out:
# True

# %%
import os
print(os.getcwd())  # Imprime el directorio actual
# Out:
# /Users/claudiorojas/Documents/Ciencia de Datos/Data SFJ/2024/PAES

# %%
df = pd.read_csv(PAES2025, sep=';', dtype={'Columna35': str})
# Out:
# <ipython-input-5-6232deca641a>:1: DtypeWarning: Columns (35) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(PAES2025, sep=';', dtype={'Columna35': str})

# %%
df = pd.read_csv(PAES2025, sep=';', low_memory=False)

# %%
# b) Calcular promedios por RBD para estudiantes con SITUACION_EGRESO = 1
filtered_data = df[df['SITUACION_EGRESO'] == 1]
columns_to_average = ['CLEC_REG_ACTUAL', 'MATE1_REG_ACTUAL', 'MATE2_REG_ACTUAL', 'HCSOC_REG_ACTUAL', 'CIEN_REG_ACTUAL']
rbd_averages = filtered_data.groupby('RBD')[columns_to_average].mean().reset_index()

# %%
# c) Calcular el promedio de CLEC_REG_ACTUAL y MATE1_REG_ACTUAL por RBD
columns_paes = ['CLEC_REG_ACTUAL', 'MATE1_REG_ACTUAL']
rbd_paes_average = filtered_data.groupby('RBD')[columns_paes].mean()
rbd_paes_average['PAES_PROMEDIO'] = rbd_paes_average.mean(axis=1)
rbd_paes_average = rbd_paes_average.reset_index()

# %%
# d) Crear un ranking de colegios basado en PAES_PROMEDIO
rbd_paes_average['RANK'] = rbd_paes_average['PAES_PROMEDIO'].rank(ascending=False, method='min')
rbd_paes_average = rbd_paes_average.sort_values('PAES_PROMEDIO', ascending=False).reset_index(drop=True)

# %%
# Función para consultar el lugar de un colegio dado su RBD
def obtener_posicion(rbd):
    resultado = rbd_paes_average[rbd_paes_average['RBD'] == rbd]
    if resultado.empty:
        return f"El RBD {rbd} no se encuentra en el ranking."
    else:
        return resultado[['RBD', 'PAES_PROMEDIO', 'RANK']]

# %%
# Mostrar resultados
print("Promedios obtenidos por estudiantes para cada RBD:\n", rbd_averages)
print("\nPromedio PAES por RBD:\n", rbd_paes_average)
# Out:
# Promedios obtenidos por estudiantes para cada RBD:
#            RBD  CLEC_REG_ACTUAL  MATE1_REG_ACTUAL  MATE2_REG_ACTUAL  \
# 0         1.0       325.563218        347.195402        120.816092
# 1         4.0       573.246305        615.344828        214.714286
# 2         5.0       493.675000        517.725000        146.400000
# 3         7.0       387.380952        403.433862        189.582011
# 4         8.0       554.297872        591.255319        180.659574
# ...       ...              ...               ...               ...
# 3287  41899.0       613.060606        642.000000        309.696970
# 3288  42158.0       194.533333        182.600000         40.800000
# 3289  42166.0       211.750000        188.000000        225.750000
# 3290  42168.0       340.642857        363.642857        107.000000
# 3291  42178.0       613.000000        696.888889        221.111111
#
#       HCSOC_REG_ACTUAL  CIEN_REG_ACTUAL
# 0           166.356322       202.701149
# 1           282.822660       353.137931
# 2           239.558333       261.650000
# 3           227.052910       246.211640
# 4           301.191489       365.063830
# ...                ...              ...
# 3287        211.121212       432.969697
# 3288         17.733333       124.866667
# 3289        124.750000       148.333333
# 3290        202.642857       130.785714
# 3291        378.333333       355.111111
#
# [3292 rows x 6 columns]
#
# Promedio PAES por RBD:
#            RBD  CLEC_REG_ACTUAL  MATE1_REG_ACTUAL  PAES_PROMEDIO    RANK
# 0     12036.0       803.250000        964.166667     883.708333     1.0
# 1      8862.0       789.989899        951.676768     870.833333     2.0
# 2      3204.0       812.538462        922.923077     867.730769     3.0
# 3      8871.0       784.276923        947.015385     865.646154     4.0
# 4      8998.0       790.838710        933.225806     862.032258     5.0
# ...       ...              ...               ...            ...     ...
# 3287  25698.0        47.459459         48.891892      48.175676  3288.0
# 3288  31220.0        31.400000         31.733333      31.566667  3289.0
# 3289  16461.0         0.000000          0.000000       0.000000  3290.0
# 3290  41173.0         0.000000          0.000000       0.000000  3290.0
# 3291   7970.0         0.000000          0.000000       0.000000  3290.0
#
# [3292 rows x 5 columns]

# %%
# Ejemplo de consulta de ranking
rbd = int(input("\nIngrese el RBD para consultar el ranking: "))
print(obtener_posicion(rbd))
# Out:
# Ingrese el RBD para consultar el ranking:  7700
#         RBD  PAES_PROMEDIO   RANK
# 145  7700.0     755.480198  146.0
